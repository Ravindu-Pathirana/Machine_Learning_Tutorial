# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('Iris.csv')
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.shape
# Out:
# (150, 6)

# %%
data.Species.value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
x=data.iloc[:,1:5]
y=data.iloc[:,5]

# %%
x.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
y.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Species, dtype: object

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = scaler.fit_transform(x)
x[:5]
# Out:
# array([[-0.90068117,  1.03205722, -1.3412724 , -1.31297673],
#        [-1.14301691, -0.1249576 , -1.3412724 , -1.31297673],
#        [-1.38535265,  0.33784833, -1.39813811, -1.31297673],
#        [-1.50652052,  0.10644536, -1.2844067 , -1.31297673],
#        [-1.02184904,  1.26346019, -1.3412724 , -1.31297673]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((120, 4), (30, 4), (120,), (30,))

# %% [markdown]
# Model Training Using KNN (K-Nearest Neighbours Algorithm)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
pred=knn.predict(x_test)
pred[:5]
# Out:
# array(['Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-virginica'], dtype=object)

# %%
y_test[:5]
# Out:
# 67     Iris-versicolor
# 103     Iris-virginica
# 66     Iris-versicolor
# 33         Iris-setosa
# 121     Iris-virginica
# Name: Species, dtype: object

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test, pred)
accuracy
# Out:
# 0.9333333333333333

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test, pred)
cm
# Out:
# array([[14,  1,  0],
#        [ 0,  6,  1],
#        [ 0,  0,  8]])

# %%
result=pd.DataFrame({'Actual':y_test, 'Predicted':pred})
result
# Out:
#               Actual        Predicted
# 67   Iris-versicolor  Iris-versicolor
# 103   Iris-virginica   Iris-virginica
# 66   Iris-versicolor  Iris-versicolor
# 33       Iris-setosa      Iris-setosa
# 121   Iris-virginica   Iris-virginica
# 28       Iris-setosa      Iris-setosa
# 43       Iris-setosa      Iris-setosa
# 54   Iris-versicolor  Iris-versicolor
# 55   Iris-versicolor  Iris-versicolor
# 81   Iris-versicolor  Iris-versicolor
# 8        Iris-setosa      Iris-setosa
# 20       Iris-setosa      Iris-setosa
# 146   Iris-virginica   Iris-virginica
# 137   Iris-virginica   Iris-virginica
# 117   Iris-virginica   Iris-virginica
# 4        Iris-setosa      Iris-setosa
# 41       Iris-setosa  Iris-versicolor
# 2        Iris-setosa      Iris-setosa
# 34       Iris-setosa      Iris-setosa
# 45       Iris-setosa      Iris-setosa
# 31       Iris-setosa      Iris-setosa
# 3        Iris-setosa      Iris-setosa
# 136   Iris-virginica   Iris-virginica
# 110   Iris-virginica   Iris-virginica
# 83   Iris-versicolor   Iris-virginica
# 46       Iris-setosa      Iris-setosa
# 116   Iris-virginica   Iris-virginica
# 47       Iris-setosa      Iris-setosa
# 98   Iris-versicolor  Iris-versicolor
# 18       Iris-setosa      Iris-setosa

# %%
correct_sum=[]
for k in range(1,21):
    knn=KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train, y_train)
    pred=knn.predict(x_test)
    accuracy=accuracy_score(y_test, pred)
    correct = np.sum(pred == y_test)
    correct_sum.append((k,correct,accuracy))
correct_sum
# Out:
# [(1, np.int64(28), 0.9333333333333333),
#  (2, np.int64(26), 0.8666666666666667),
#  (3, np.int64(28), 0.9333333333333333),
#  (4, np.int64(29), 0.9666666666666667),
#  (5, np.int64(29), 0.9666666666666667),
#  (6, np.int64(29), 0.9666666666666667),
#  (7, np.int64(29), 0.9666666666666667),
#  (8, np.int64(29), 0.9666666666666667),
#  (9, np.int64(29), 0.9666666666666667),
#  (10, np.int64(29), 0.9666666666666667),
#  (11, np.int64(29), 0.9666666666666667),
#  (12, np.int64(29), 0.9666666666666667),
#  (13, np.int64(29), 0.9666666666666667),
#  (14, np.int64(29), 0.9666666666666667),
#  (15, np.int64(29), 0.9666666666666667),
#  (16, np.int64(29), 0.9666666666666667),
#  (17, np.int64(29), 0.9666666666666667),
#  (18, np.int64(29), 0.9666666666666667),
#  (19, np.int64(29), 0.9666666666666667),
#  (20, np.int64(29), 0.9666666666666667)]
