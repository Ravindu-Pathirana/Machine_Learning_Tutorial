# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('kyphosis.csv')
data.sample(5)
# Out:
#    Kyphosis  Age  Number  Start
# 37  present   52       5      6
# 55   absent   72       5     15
# 4    absent    1       4     15
# 73   absent  206       4     10
# 56   absent    2       3     13

# %%
x= data.drop('Kyphosis', axis=1)
y= data['Kyphosis']

# %%
y.value_counts()
# Out:
# Kyphosis
# absent     64
# present    17
# Name: count, dtype: int64

# %%
y.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Kyphosis'>

# %%
# %pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.14.1)
# Requirement already satisfied: numpy<3,>=1.25.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from imbalanced-learn) (2.3.5)
# Requirement already satisfied: scipy<2,>=1.11.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from imbalanced-learn) (1.16.3)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from imbalanced-learn) (1.8.0)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from imbalanced-learn) (0.1.5)
# Requirement already satisfied: joblib<2,>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from imbalanced-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from imbalanced-learn) (3.6.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Undersampling

# %%
from imblearn.under_sampling import RandomUnderSampler
undersamplr = RandomUnderSampler(sampling_strategy='majority')
x_under, y_under = undersamplr.fit_resample(x, y)

# %%
y_under.value_counts()
# Out:
# Kyphosis
# absent     17
# present    17
# Name: count, dtype: int64

# %%
y_under.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Kyphosis'>

# %% [markdown]
# ## Oversampling

# %%
from imblearn.over_sampling import RandomOverSampler
oversampler = RandomOverSampler(sampling_strategy='minority')
x_over, y_over = oversampler.fit_resample(x, y)

# %%
y_over.value_counts()
# Out:
# Kyphosis
# absent     64
# present    64
# Name: count, dtype: int64

# %%
y_over.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Kyphosis'>

# %% [markdown]
# ## SMOTE Technique

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(sampling_strategy='minority')
x_smote, y_smote = smote.fit_resample(x, y)

# %%
y_smote.value_counts()
# Out:
# Kyphosis
# absent     64
# present    64
# Name: count, dtype: int64

# %%
y_smote.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Kyphosis'>
